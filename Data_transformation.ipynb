# %% [markdown]
# # Dataset Creation (Phase 2)

# %% [markdown]
# #### Input:
#    dataset.json created in stage 1
# #### Output:
#    dataset.csv
# #### Algorithm:
#    a) Simple loop statement will do the trick

# %%
import json
from time import time
import os
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
import re

# %%
def stem_words(text):
    text = text.split()
    stemmer = WordNetLemmatizer()
    stemmed_words = [stemmer.lemmatize(word) for word in text]
    text = " ".join(stemmed_words)
    return text

# %%
def make_lower_case(text):
    return text.lower()

# %%
def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text

# %%
def remove_removeletters(text):
    return re.sub("[0-9]", "", text)

# %%
def read_json():
    processed_dict = {}
    with open("dataset.json", "r") as fp:
        processed_dict = json.load(fp)
    fp.close()
    return processed_dict

# %%
def filter_text(text):
    return remove_removeletters(remove_punctuation(stem_words(make_lower_case(text))))

# %%
abstract = "abstract/"

# %%
def create_dataset(processed_dict):
    
    files = set()
    
    for file in processed_dict:
        
        for key in file:

            if "keywords" not in file[key]:
                continue
            
            if key in files:
                continue

            files.add(key)

            filter_filename = key.replace(",", "")
            with open(abstract + filter_filename.split(".")[0] + ".txt", "w", encoding="utf-8") as fp:
                fp.write(file[key]["abstract"])
            fp.close()
        
            weights = list(file[key]["keywords"].keys())
            keywords = list(file[key]["keywords"].values())
            
            for i in range(len(keywords)):
                cleaned_text = filter_text(keywords[i])
                with open("dataset.csv", "a") as fp:
                    fp.write(filter_filename + "," + cleaned_text + "," + str(weights[i]))
                    fp.write("\n")
                fp.close()
                
            print("File {} is written".format(key))

# %%
def main():
    print("\n==========Welcome to phase 2=============\n")
    start = time()
    print("Time: 0")
    processed_dict = read_json()
    create_dataset(processed_dict)
    end = time()
    print("\nTime: {}".format(end-start))
    #os.remove("dataset.json")
    print("\n===========Phase 2 ended=============\n")

# %%
if __name__ == "__main__":
    main()
# Out:
# ==========Welcome to phase 2=============
#
# Time: 0
# File User Application for Shop Floor Automation using Data Analytics_14.pdf is written
# File SCRUTINIZING BEHAVIOUR OF VM COMMUNICATION.pdf is written
# File Plant Disease Detection Using Deep Learning Techniques.pdf is written
# File CONTEXTUAL RECOMMENDATION AND_SUMMARIZATION OF ENTERPRISE_COMMUNICATION.pdf is written
# File Speech and Speaker Recognition_for Home Security System.pdf is written
# File Chatbot for automated customer support.pdf is written
# File Disease Diagnosis Using Nadi Parikshan_44.pdf is written
# File PLATFORM FOR BUILDING ENTERPRISE_SOLUTIONS (WORKFLOW MANAGER).pdf is written
# File FASHION RECOMMENDATION AND_DESIGN USING MACHINE LEARNING.pdf is written
# File Object Based Visual Sentiment Analysis.pdf is written
# File META DATA AND CONTENT BASED YOUTUBE_VIDEO TAG GENERATION.pdf is written
# File PATTERN DETECTION AND_RECOGNITION SYSTEM FOR VEHICLES.pdf is written
# File ANALYSIS OF PRIVACY POLICIES VIA_MACHINE LEARNING.pdf is written
# File Human detection and gender classification using Machine Learning based approach_10.pdf is written
# File Text Mining Algorithms For Assessment of Answersheets.pdf is written
# File HPC clodburst using docker_42.pdf is written
# File Stock Prediction Using Technical Analysis.pdf is written
# File INTELLIGENT FINANCIAL PORTFOLIO.pdf is written
# File ELECTION RESULT PREDICTION USING_SENTIMENTAL ANALYSIS ON TWITTER DATA.pdf is written
# File COMPREHENSIVE DEVELOPER ASSISTANT_(CODA).pdf is written
# File SISA_ SECURING IMAGES USING_SELECTIVE ALTERATION.pdf is written
# File REBRACE _ AN INTELLIGENT SOLUTION FOR_SUPPORT HELPDESK AUTOMATION_20.pdf is written
# File CONSTRUCT 3D COMPUTER OBJECTS_FROM MULTIPLE VIEWS.pdf is written
# File Question Pair Similarity and Text Summarization.pdf is written
# File DRONE DROID_58.pdf is written
# File AUTOMATED GLAUCOMA DETECTION.pdf is written
# File Suspect Analysis using Machine Learning.pdf is written
# File Real Time Web Analytics_59.pdf is written
# File Disease prediction using machine learning_55.pdf is written
# File POLICE CONTROL ROOM RUNTIME_ANALYSIS.pdf is written
# File ___BREAST CANCER DETECTION AND_DIAGNOSIS USING MACHINE LEARNING___.pdf is written
# File Report_Final_zip_9.pdf is written
# File Crop yield estimation using Data mining techniques..pdf is written
# File AI- ASSISTED POTENTIAL HEALTH RISK_PREDICTOR.pdf is written
# File E-GLOVE_ A HEALTH MONITORING_SYSTEM USING WEARABLE COMPUTING,_IoT AND DATA MINING.pdf is written
# File BE_PROJECT_REPORT_FORMAT_TERM_II_LATEX_FILE_68.pdf is written
# File A CRYPTOSYSTEM FOR ENCRYPTION OF_DATA USING IMAGES FOR KEY_GENERATION.pdf is written
# File SIMULATOR FOR BMC BLADELOGIC SERVER_AUTOMATION_35.pdf is written
# File A fast distributed key-value store based on_the RAFT protocol and Judy arrays_37.pdf is written
# File VEHICULAR SECURITY SYSTEM_3.pdf is written
# File Differentiating Between Attacker And Legitimate VM.pdf is written
# File APPLICATION TO DETERMINE THE SAFEST ROUTE USING CRIME JANALYSIS VIA DECISION TREE JALGORITHM_78.pdf is written
# File lazynotes_54.pdf is written
# File Machine Learning Based Network Traffic Classification.pdf is written
# File SUPPLY CHAIN MANAGEMENT FOR_AUTOMOBILE INDUSTRY.pdf is written
# File Conditional GIF Generation Using GANS.pdf is written
# File Intelligent Holiday Planner.pdf is written
# File IOT BASED BIKE BLACK BOX.pdf is written
# File MACHINE LEARNING AGENT FOR GAME_DEVELOPMENT.pdf is written
# File Automatic SQL Query Formation using NLP.pdf is written
# File Context aware book recommendation system_27.pdf is written
# File E-Care-Android Application For Health Monitoring_73.pdf is written
# File Face Recognition in Videos.pdf is written
# File Dynamic Forms - UI UX.pdf is written
# File self learning cognitive system using large scale neural network_21.pdf is written
# File OpenAir Interface.pdf is written
# File INTELLIGENT TOLL AUTOMATION SYSTEM_50.pdf is written
# File Exploring alternative approaches to control forwarding path of packets in virtual networks_4.pdf is written
# File USE OF COGNITIVE TECHNOLOGIES TO AID_DECISION MAKING IN THE INDIAN_JUDICIARY.pdf is written
# File GEO-ENABLED PROPERTY TAX.pdf is written
# File Real Time Image Description using Deep Learning.pdf is written
# File QUERY BASED CAR MAKE AND MODEL_RECOGNITION SYSTEM USING DEEP_LEARNING.pdf is written
# File Interactive Store System_12.pdf is written
# File Visualization As A Sevice_11.pdf is written
# File PROVIDE CHATBOT FUNCTIONALITY IN BMC REMEDY AR SYSTEM PLATFORM.pdf is written
# File IMAGE GENERATION OF HUMAN FACES FROM_TEXT DESCRIPTION USING GENERATIVE_ADVERSARIAL NETWORKS.pdf is written
# File System To Guide Visually Impaired People_47.pdf is written
# File Novice Tourist Recommendation System.pdf is written
# File ENHANCED FRAMEWORK FOR TRUE_SIGHT NETWORK AUTOMATION.pdf is written
# File Video Summarization using clustering techniques.pdf is written
# File Galaxy Morphology Prediction using Convolutional_Neural Networks_64.pdf is written
# File Robust Speaker Recognition System for  online authentication and real-time verification.pdf is written
# File ONLINE REVIEW ANALYSIS.pdf is written
# File SMART STUDY GUIDE USING MACHINE_LEARNING.pdf is written
# File Detection Of Diabetic Retinopathy Detection Using Computer Vision.pdf is written
# File FOOD QUALITY INSPECTION USING_COMPUTER VISION.pdf is written
# File Intelligent Recruitment Assistant_33.pdf is written
# File Automatic Notification Bot Using Web JMining for Event Analysis_72.pdf is written
# File CONVERSION OF VIDEO CONTAINING SIGN_LANGUAGE TO TEXTUAL FORMAT.pdf is written
# File Virtual Arts Gallery_75.pdf is written
# File A SYSTEM FOR LANGUAGE TRANSLATION.pdf is written
# File Resume analysis through machine learning_43.pdf is written
# File 2D TO 3D IMAGE CONVERSION USING_MACHINE LEARNING APPROACH.pdf is written
# File Emergency Blood Requirement system_48.pdf is written
# File Predicting_MyersBriggs_Personality_type.pdf is written
# File EFFICIENT DIABETES RISK ASSESSMENT IN_PATIENTS USING MACHINE LEARNING_ALGORITHMS.pdf is written
# File COMPLIANCE ENGINE FOR DATABASES.pdf is written
# File EMOTION BASED MUSIC PLAYER.pdf is written
# File Product Attribute Extraction And Comparator_26.pdf is written
# File Expressive English Text-to-Speech Synthesis System_7.pdf is written
# File Distracted_Driver_Detection_ Using_Deep_Learning.pdf is written
# File Text to Image Generation.pdf is written
# File VISUALLY IMPAIRED ASSISTANT SYSTEM.pdf is written
# File Generic User Activity Analysis And Prediction_34.pdf is written
# File Marathi translation using wsd concept_36.pdf is written
# File Biometric Based RTO License Checking_And Fine system.pdf is written
# File Web_Vulnerability Scanner.pdf is written
# File Android Malware Detection Using Machine Learning_67.pdf is written
# File OptimisedDeliveryManagementSystemForE-Commerce_40.pdf is written
# File Interactive ChatBot_5.pdf is written
# File SECURITY IN IOT_23.pdf is written
# File Intelligent transportation system_71.pdf is written
# File Metering and Throttling for Remedy_Applications_76.pdf is written
# File NOTIFICATION SERVICE FOR CMDB.pdf is written
# File Text Analysis for Indian Literature.pdf is written
# File IOT BASED HEALTH ALLIANCE HELP DESK_41.pdf is written
# File Classification of abstract images using machine learning_66.pdf is written
# File Article Classification and Recommendation system.pdf is written
# File analyze online clickstream data to understand user intent and personalized ads_25.pdf is written
# File MANAGING LAND OWNERSHIP USING_BLOCKCHAIN.pdf is written
# File Automated Sound Quality Enhancer Assistant.pdf is written
# File Multi-document Abstractive Summarization_1.pdf is written
# File PHYSICAL WEB WITH VENDING MACHINE_77.pdf is written
# File Development of Intelligent automated indoor_navigator and assistance system.pdf is written
# File Generic SDK for zephyr OS to connect AWS IoT cloud.pdf is written
# File AUTOMATED FINANCIAL PORTFOLIO BUILDING_57.pdf is written
# File HIRING DECISION SUPPORT SYSTEM_13.pdf is written
# File Music Discovery Using Content Based Paradigms.pdf is written
# File RE-ADMISSION RISK PREDICTION FOR_HEART ATTACK.pdf is written
# File Integration of DeepLearning4j with Apache Apex framework_60.pdf is written
# File IntelligentAssistant.pdf is written
# File SMART BUSINESS CONTINUITY APPLICATION.pdf is written
# File DIMENSION EXTRACTION OF AN OBJECT_USING MACHINE VISION.pdf is written
# File BEAM-DIGITIZING_CONTENT_IN_ADVERTISING.pdf is written
# File CREDIT CARD FRAUD DETECTION_SYSTEM.pdf is written
# File Virtual Lab for Electronics_29.pdf is written
# File AIR POLLUTION DETECTION WITH_NAVIGATION SYSTEM.pdf is written
# File AUTOMATED BRAKING TEST FOR_VEHICLE LICENSES.pdf is written
# File NETWORK MONITORING TOOL_45.pdf is written
# File AUTO PAINTER_ TEXT TO IMAGE_SYNTHESIS.pdf is written
# File INSIDER THREAT DETECTION AND_ADAPTIVE TWO FACTOR_AUTHENTICATION SYSTEM FOR CLOUD_COMPUTING BY ANALYZING SYSTEM_LOGS.pdf is written
# File Interactive User Behaviour Analysis and_Recommendation System Using Web Log_Mining_15.pdf is written
# File QA GENERATION APPLICATION USING NLP.pdf is written
# File PIXTALK_ PICTURE EXCHANGE COMMUNICATION_FOR AUTISM SPECTRUM DISORDER IN CHILDREN_USING MACHINE LEARNING.pdf is written
# File Improving performance of Virtual Machines by Virtio Bridge Bypass for PCI devices_69.pdf is written
# File Analyzing Product Image-Metadata Based On Click Through Rate For Advertisement Logistics_61.pdf is written
# File NextGen_Router_17.pdf is written
# File TEXT TO IMAGE SYNTHESIS IN FASHION.pdf is written
# File Analysis of Indian Stock Market Analysts.pdf is written
# File CONVERSION OF MARATHI TEXT TO_BRAILLE USING OPTICAL CHARACTER_RECOGNITION.pdf is written
# File Creating server on android phone using NanoHTTPD.pdf is written
# File Human Action Recognition System.pdf is written
# File Generic Replicator Framework.pdf is written
# File Porting Zephyr OS.pdf is written
# File Re-Sequencing of Associated News Articles in a Feed Using_Sentiment Analysis_28.pdf is written
# File Live process migration in mobil e env_63.pdf is written
# File Volunteer Automation For NGO_79.pdf is written
# File SIGN LANGUAGE RECOGNITION.pdf is written
# File Image Generation in the Style of Artists Using Deep Learning_65.pdf is written
# File Text summarization of any doc using lsa.pdf is written
# File Project Mycroft AI.pdf is written
# File Generic_Traffic_Shaper_19.pdf is written
# File Accelerating Foreign Language Learning_62.pdf is written
# File Disease Detection using ayurvedic pulse diagnosis.pdf is written
# File RECOMMENDATION USING CONTENT_BASED IMAGE RETRIEVAL.pdf is written
# File ETHEREUM BASED BLOCKCHAIN_IMPLEMENTATION OF PEER REVIEW_SYSTEM.pdf is written
# File CLASSIFYING USERS AND IDENTIFYING_USER INTERESTS BASED ON SEMANTIC AND_CONTEXTUAL ANALYSIS.pdf is written
# File DEEP LEARNING IN MEDICAL IMAGE_ANALYSIS.pdf is written
# File An IoT GATEWAY FOR INTERFACING BLE PERIPHERALS TO CLOUD.pdf is written
# File Price Elasticity and Optimization_6.pdf is written
# File VIRTUAL MACHINE COMMUNICATION_ANALYSIS.pdf is written
# File COGNITIVE INTELLIGENCE AND_KNOWLEDGE BASED CLASSIFICATION_AND REASONING.pdf is written
# File Visual Question Answering Using Deep_Learning_30.pdf is written
# File CustomerDecisionSupportSystem_39.pdf is written
# File Crop_disease_detection.pdf is written
# File Ocr Pre-Processing.pdf is written
# File Quick Learning Tool.pdf is written
# File INTELLIGENT CYBER SECURITY SYSTEM.pdf is written
# File DIRECT TRANSFER FROM DATA DEVICES_56.pdf is written
# File ANALYSIS OF WORKLOAD AND ITS_CHARACHTERISITICS PROVIDED BY THE_HYPERVISOR AND RECOMMEND_OPTIMAL FIT IN CLOUD.pdf is written
# File AI BUDDY.pdf is written
# File 3D-image terrain classification using machine learning_46.pdf is written
# File Indoor Positioning system with BLE beacons using voronoi mapping.pdf is written
# File SOFTWARE GPU UTILITIES_32.pdf is written
# File Crop Production Estimation.pdf is written
# File OPTICAL COHERENCE_TOMOGRAPHY(OCT) REPORT_GENERATOR.pdf is written
# File CODE IMPACT ANALYZER.pdf is written
# File Developing Cross Platform App For Farmers For Suggesting Agricultural Products.pdf is written
# File RMI_Based_Custom_Adapter_8.pdf is written
# File Video Summarization_31.pdf is written
# File Digital_College.pdf is written
# File PERSONALITY PREDICTION SYSTEM_USING TWITTER DATA.pdf is written
# File NOBODY PARKS HERE.pdf is written
# File DETECTING CERVICAL ABNORMALITIES_USING MACHINE LEARNING.pdf is written
# File Implementation of QoE-QoS in SDN_52.pdf is written
# File EMPREAL_SOFTWARE_FOR_SOLAR_POWERED_ROOFS.pdf is written
# File Cloud Switch with Cmpatible Library for IoT Devices.pdf is written
# File MICRO VIDEO RECOMMENDATION_SYSTEM FOR CONTENT WRITER.pdf is written
# File DynamicFoodPricing.pdf is written
# File N-SCALAR.pdf is written
# File GPS SUPPORTED CITY BUS TRACKING AND TRIP PLANNER_53.pdf is written
# File GESTURE AWARE INTERACTIVE_PRESENTATION SYSTEM.pdf is written
# File SMART CITY GARBAGE CAN_16.pdf is written
# File OBSTACLE AVOIDANCE USING_REINFORCEMENT LEARNING.pdf is written
# File UCAN-Unified Communication for Assisting Novice.pdf is written
# File SENTIMENT ANALYSIS ON TWITTER JDATA_74.pdf is written
# File Multikeyword ranked search over encrypted data.pdf is written
# File TRANSACTION MONITORING IN PUBLIC_WELFARE PROJECTS USING SMART_CONTRACTS.pdf is written
# File DEMAND FORECASTING FOR INVENTORY_OPTIMIZATION.pdf is written
# File Adaptive Traffic Congestion Control.pdf is written
# File DETECTING STUDENT___S ENGAGEMENT IN_LECTURE USING DEEP LEARNING.pdf is written
# File CONTEXTUAL ANALYSIS BASED ON_SUMMARIZED TEXT OF CONVERSATION.pdf is written
# File Biomedical Tumor Segmentation.pdf is written
# File Smart_Surveillance System_49.pdf is written
# File ANSWERING OPEN ENDED QUESTIONS_BASED ON IMAGES USING DEEP_LEARNING APPROACH.pdf is written
# File Dynamic load balancing of web servers.pdf is written
# File Analysis of Videos using Deep Learning and High Performance_Computing.pdf is written
# File Personality Prediction System.pdf is written
# File Transparent Distributed Computing for CUDA_24.pdf is written
# File A NALYSIS OF G ENE R EGULATION USING_D EEP L EARNING.pdf is written
# File AUDIT AND COMPLIANCE IN SERVICE_MANAGEMENT USING BLOCKCHAIN.pdf is written
# File IT SKILLS TRACKING AND EMPLOYEE ASSESSMEN_2.pdf is written
# File AUTOMATIC INFORMATION EXTRACTION_FROM TEXT DOCUMENTS.pdf is written
# File HATE SPEECH DETECTION ON TWITTER_USING SENTIMENT ANALYSIS.pdf is written
# File Banking_Recommendation_system.pdf is written
#
# Time: 10.041995525360107
#
# ===========Phase 2 ended=============

# %% [markdown]
# # End of phase 2
