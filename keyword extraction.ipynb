# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
from nltk.tokenize import word_tokenize
import os
import json
import re
import pytextrank
import spacy
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def convert_pdf_to_txt(path, pageno=[]):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()
    all_pages_data = []
    
    if len(pageno) == 0:
        all_pages_data = {}
        all_pages_data["filename"] = path
        all_pages_data["data"] = ""
        all_pages_data["title"] = ""

    for pageNo, page in enumerate(PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True)):
        interpreter.process_page(page)
        data = retstr.getvalue()
        
        if pageNo == 0:
            try:
                result = re.search("report on (.*) submitted", data.replace("\n", " ").lower())
                project = result.group(1)
                all_pages_data["title"] = project.strip()
            except:
                raise Exception("Error in finding project name")
        
        if len(pageno) == 0:
            all_pages_data["data"] += data
        elif pageNo in pageno:
                all_pages_data.append(data)
        
        data = ""
        retstr.truncate(0)
        retstr.seek(0)
        
    fp.close()
    device.close()
    retstr.close()
    return all_pages_data

# %%
def get_stopwords():
    with open("long_stopwords.txt", "r") as fp:
        stopwords_long = fp.read().split("\n")
    common_stopwords = list(stopwords.words("english"))
    stopwords_list = list(set(stopwords_long + common_stopwords))
    return stopwords_list

# %%
stopwords_list = get_stopwords()
lemmatizer = WordNetLemmatizer()
knowledge_base = json.load(open("./knowledge_base.json"))
reports = "./reports_doc/"

# %%
nlp = spacy.load("en_core_web_md")
tr = pytextrank.TextRank()
nlp.add_pipe(tr.PipelineComponent, name="textrank", last=True)
output_dict = {}

# %%
def clean(text):
    text = text.replace(",", " ").replace(":", " ")
    text = str(text).lower()
    printable = set(string.printable)
    text = "".join(list(filter(lambda x: x in printable, text)))
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in string.punctuation]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return " ".join([word for word in tokens if word not in stopwords_list])

# %%
def extract_knowledge(text):
    tokens = word_tokenize(text)
    languages_extracted = [language for language in tokens if language in knowledge_base["languages"]]
    frameworks_extracted = [framework for framework in tokens if framework in knowledge_base["frameworks"]]
    dbs_extracted = [db for db in tokens if db in knowledge_base["dbs"]]
    libraries_extracted = [token for token in tokens if token in knowledge_base["libraries"]]
    return {
        "languages": list(set(languages_extracted)),
        "frameworks": list(set(frameworks_extracted)),
        "dbs": list(set(dbs_extracted)),
        "libraries": list(set(libraries_extracted))
    }

# %%
def filter_numbers(x):
    return re.sub("[^A-Za-z ]", "", str(x))

# %%
def parse_docs(file):
    
    try:
        
        # Reading dictionary
        
        processed_dict = convert_pdf_to_txt(reports + file)
        text = clean(processed_dict["data"])
        
        # Extracting knowledge by rules
        knowledge_extracted = extract_knowledge(text)
        
        doc = nlp(text)
        data = []
        
        # Text rank for keyword extraction
        for p in doc._.phrases:
            data.append([p.rank, p.text])
        
        # Filter keywords
        data = np.array(data)
        df = pd.DataFrame(data, columns=["rank", "keyword"])
        df["keyword"] = df["keyword"].apply(filter_numbers)
        df["keyword"] = df["keyword"].apply(lambda x: re.sub("b[0-9]{9}", "", str(x)))
        df["keyword"] = df["keyword"].apply(lambda x: str(x).strip())
        df["len"] = df["keyword"].apply(lambda x: len(str(x)))
        df = df[df["len"] >= 5]
        tf = TfidfVectorizer(analyzer="word", ngram_range=(1, 3), min_df=3, stop_words="english")
        tf.fit_transform(df["keyword"])
        
        # Choose upto 3-grams
        
        ngrams = []
        for f in tf.get_feature_names():
            if len(f.split(" ")) > 1:
                ngrams.append(f)
        
        # Collect all the information
        
        information_extracted = {
            "title": processed_dict["title"],
            "filename": processed_dict["filename"],
            "data": text,
            "keywords": ngrams,
            "libraries": knowledge_extracted["libraries"],
            "languages": knowledge_extracted["languages"],
            "frameworks": knowledge_extracted["frameworks"],
            "dbs": knowledge_extracted["dbs"]
        }
        
        return information_extracted
        
    except:
        raise Exception("Something went wrong")

# %%
def main():

    files = os.listdir(reports)
    count = 0
    
    discarded_files = []
    
    for file in files:
        
        try:
            output_dict[reports + file] = parse_docs(file)
            print("Parsing file {} is done".format(file))
            count += 1
        except:
            discarded_files.append(file)
            print("Error in parsing {}".format(file))
            
    print("Total files: {}".format(len(files)))
    print("Discarded files: {}".format(len(files)-count))
        
    json.dump(output_dict, open("./dataset_1.json", "w"))
    
    for file in discarded_files:
        os.remove(reports + file)

# %%
# %%time
main()
# Out:
# Parsing file 1.pdf is done
# Parsing file 102.pdf is done
# Parsing file 103.pdf is done
# Parsing file 18.pdf is done
# Parsing file 22.pdf is done
# Parsing file 24.pdf is done
# Parsing file 25.pdf is done
# Parsing file 29.pdf is done
# Parsing file 2D TO 3D IMAGE CONVERSION USING_MACHINE LEARNING APPROACH.pdf is done
# Parsing file 34.pdf is done
# Parsing file 35.pdf is done
# Parsing file 38.pdf is done
# Parsing file 3D-image terrain classification using machine learning_46.pdf is done
# Parsing file 50.pdf is done
# Parsing file 52.pdf is done
# Parsing file 54.pdf is done
# Parsing file 56.pdf is done
# Parsing file 76.pdf is done
# Parsing file 85.pdf is done
# Parsing file 90.pdf is done
# Parsing file 91.pdf is done
# Parsing file 93.pdf is done
# Parsing file 97.pdf is done
# Parsing file 99.pdf is done
# Parsing file A CRYPTOSYSTEM FOR ENCRYPTION OF_DATA USING IMAGES FOR KEY_GENERATION.pdf is done
# Parsing file A fast distributed key-value store based on_the RAFT protocol and Judy arrays_37.pdf is done
# Parsing file A NALYSIS OF G ENE R EGULATION USING_D EEP L EARNING.pdf is done
# Parsing file A SYSTEM FOR LANGUAGE TRANSLATION.pdf is done
# Parsing file Accelerating Foreign Language Learning_62.pdf is done
# Parsing file Adaptive Traffic Congestion Control.pdf is done
# Parsing file Advance_Database_Security_Using_Secure_Layer.pdf is done
# Parsing file AI BUDDY.pdf is done
# Parsing file AI- ASSISTED POTENTIAL HEALTH RISK_PREDICTOR.pdf is done
# Parsing file AIR POLLUTION DETECTION WITH_NAVIGATION SYSTEM.pdf is done
# Parsing file An IoT GATEWAY FOR INTERFACING BLE PERIPHERALS TO CLOUD.pdf is done
# Parsing file Analysis of Indian Stock Market Analysts.pdf is done
# Parsing file ANALYSIS OF PRIVACY POLICIES VIA_MACHINE LEARNING.pdf is done
# Parsing file Analysis of Videos using Deep Learning and High Performance_Computing.pdf is done
# Parsing file ANALYSIS OF WORKLOAD AND ITS_CHARACHTERISITICS PROVIDED BY THE_HYPERVISOR AND RECOMMEND_OPTIMAL FIT IN CLOUD.pdf is done
# Parsing file Analytics Dashboards of E-commerce Backend_12.pdf is done
# Parsing file analyze online clickstream data to understand user intent and personalized ads_25.pdf is done
# Parsing file Analyzing Product Image-Metadata Based On Click Through Rate For Advertisement Logistics_61.pdf is done
# Parsing file ANDROID BASED SOLUTION FOR ANALYSIS OF_POST-HARVEST LOSSES AND PREVENTIVE_MEASURES USING MACHINE LEARNING_15.pdf is done
# Parsing file Android Malware Detection Using Machine Learning_67.pdf is done
# Parsing file ANSWERING OPEN ENDED QUESTIONS_BASED ON IMAGES USING DEEP_LEARNING APPROACH.pdf is done
# Parsing file APPLICATION TO DETERMINE THE SAFEST ROUTE USING CRIME JANALYSIS VIA DECISION TREE JALGORITHM_78.pdf is done
# Parsing file Applications of Deep Neural Networks in Domain Agnostic Recommendation Engine_57.pdf is done
# Parsing file Article Classification and Recommendation system.pdf is done
# Parsing file AUDIT AND COMPLIANCE IN SERVICE_MANAGEMENT USING BLOCKCHAIN.pdf is done
# Parsing file AUTO PAINTER_ TEXT TO IMAGE_SYNTHESIS.pdf is done
# Parsing file Auto-Classification of Tickets in IT Service Management_19.pdf is done
# Parsing file AUTOMATED BRAKING TEST FOR_VEHICLE LICENSES.pdf is done
# Parsing file AUTOMATED FINANCIAL PORTFOLIO BUILDING_57.pdf is done
# Parsing file AUTOMATED GLAUCOMA DETECTION.pdf is done
# Parsing file AUTOMATED LOG ANALYSIS AND FILTERING_73.pdf is done
# Parsing file Automated Power Measurement System_79.pdf is done
# Parsing file Automated Sound Quality Enhancer Assistant.pdf is done
# Parsing file AUTOMATIC INFORMATION EXTRACTION_FROM TEXT DOCUMENTS.pdf is done
# Parsing file Automatic Notification Bot Using Web JMining for Event Analysis_72.pdf is done
# Parsing file Automatic SQL Query Formation using NLP.pdf is done
# Parsing file Banking_Recommendation_system.pdf is done
# Parsing file BE49.pdf is done
# Parsing file BEAM-DIGITIZING_CONTENT_IN_ADVERTISING.pdf is done
# Parsing file BEREPORT.pdf is done
# Parsing file BE_PROJECT_REPORT_FORMAT_TERM_II_LATEX_FILE_68.pdf is done
# Parsing file BE_report_final.pdf is done
# Parsing file BE_report_final3.pdf is done
# Parsing file Biomedical Tumor Segmentation.pdf is done
# Parsing file Biometric Based RTO License Checking_And Fine system.pdf is done
# Parsing file BUSINESS ANALYTICS DASHBOARD_9.pdf is done
# Parsing file Canvazify _ Collaboration SAAS platform on mobile_devices_72.pdf is done
# Parsing file Chatbot for automated customer support.pdf is done
# Parsing file Classification of abstract images using machine learning_66.pdf is done
# Parsing file CLASSIFYING USERS AND IDENTIFYING_USER INTERESTS BASED ON SEMANTIC AND_CONTEXTUAL ANALYSIS.pdf is done
# Parsing file Cloud based Magixphone and web gaming platform_38.pdf is done
# Parsing file CODE IMPACT ANALYZER.pdf is done
# Parsing file COGNITIVE INTELLIGENCE AND_KNOWLEDGE BASED CLASSIFICATION_AND REASONING.pdf is done
# Parsing file COMPLIANCE ENGINE FOR DATABASES.pdf is done
# Parsing file COMPREHENSIVE DEVELOPER ASSISTANT_(CODA).pdf is done
# Parsing file Conditional GIF Generation Using GANS.pdf is done
# Parsing file Connected_Component_Labelling_45.pdf is done
# Parsing file CONSTRUCT 3D COMPUTER OBJECTS_FROM MULTIPLE VIEWS.pdf is done
# Parsing file Content Based Image Retrieval of T-Shirts_55.pdf is done
# Parsing file Context aware book recommendation system_27.pdf is done
# Parsing file CONTEXTUAL ANALYSIS BASED ON_SUMMARIZED TEXT OF CONVERSATION.pdf is done
# Parsing file CONTEXTUAL RECOMMENDATION AND_SUMMARIZATION OF ENTERPRISE_COMMUNICATION.pdf is done
# Parsing file CONVERSION OF MARATHI TEXT TO_BRAILLE USING OPTICAL CHARACTER_RECOGNITION.pdf is done
# Parsing file CONVERSION OF VIDEO CONTAINING SIGN_LANGUAGE TO TEXTUAL FORMAT.pdf is done
# Parsing file Creating server on android phone using NanoHTTPD.pdf is done
# Parsing file CREDIT CARD FRAUD DETECTION_SYSTEM.pdf is done
# Parsing file Crop Production Estimation.pdf is done
# Parsing file Crop yield estimation using Data mining techniques..pdf is done
# Parsing file Crop_disease_detection.pdf is done
# Parsing file CustomerDecisionSupportSystem_39.pdf is done
# Parsing file DEEP LEARNING IN MEDICAL IMAGE_ANALYSIS.pdf is done
# Parsing file DEMAND FORECASTING FOR INVENTORY_OPTIMIZATION.pdf is done
# Parsing file DESIGN FRAMEWORK FOR_E-COMMERCE APPLICATION_37.pdf is done
# Parsing file DETECTING CERVICAL ABNORMALITIES_USING MACHINE LEARNING.pdf is done
# Parsing file DETECTING STUDENT___S ENGAGEMENT IN_LECTURE USING DEEP LEARNING.pdf is done
# Parsing file Detection Of Diabetic Retinopathy Detection Using Computer Vision.pdf is done
# Parsing file Developing Cross Platform App For Farmers For Suggesting Agricultural Products.pdf is done
# Parsing file Development of Intelligent automated indoor_navigator and assistance system.pdf is done
# Parsing file DEVELO~1.PDF is done
# Parsing file Differentiating Between Attacker And Legitimate VM.pdf is done
# Parsing file Digital_College.pdf is done
# Parsing file DIMENSION EXTRACTION OF AN OBJECT_USING MACHINE VISION.pdf is done
# Parsing file DIRECT TRANSFER FROM DATA DEVICES_56.pdf is done
# Parsing file Disease Detection using ayurvedic pulse diagnosis.pdf is done
# Parsing file Disease Diagnosis Using Nadi Parikshan_44.pdf is done
# Parsing file Disease prediction using machine learning_55.pdf is done
# Parsing file Distracted_Driver_Detection_ Using_Deep_Learning.pdf is done
# Parsing file Download File.pdf is done
# Parsing file DRONE DROID_58.pdf is done
# Parsing file Dynamic Forms - UI UX.pdf is done
# Parsing file Dynamic load balancing of web servers.pdf is done
# Parsing file DynamicFoodPricing.pdf is done
# Parsing file E-Care-Android Application For Health Monitoring_73.pdf is done
# Parsing file E-GLOVE_ A HEALTH MONITORING_SYSTEM USING WEARABLE COMPUTING,_IoT AND DATA MINING.pdf is done
# Parsing file ECG MONITORING FOR DRIVER ANALYSIS_17.pdf is done
# Parsing file EFFICIENT DIABETES RISK ASSESSMENT IN_PATIENTS USING MACHINE LEARNING_ALGORITHMS.pdf is done
# Parsing file ELECTION RESULT PREDICTION USING_SENTIMENTAL ANALYSIS ON TWITTER DATA.pdf is done
# Parsing file Emergency Blood Requirement system_48.pdf is done
# Parsing file EMOTION BASED MUSIC PLAYER.pdf is done
# Parsing file ENHANCED FRAMEWORK FOR TRUE_SIGHT NETWORK AUTOMATION.pdf is done
# Parsing file ERP SYSTEM FOR A FLEXIBLE TRANSPORTATION_SERVICE_30.pdf is done
# Parsing file ETHEREUM BASED BLOCKCHAIN_IMPLEMENTATION OF PEER REVIEW_SYSTEM.pdf is done
# Parsing file Event_Driven_Process_Orchestration_59.pdf is done
# Parsing file Exploring alternative approaches to control forwarding path of packets in virtual networks_4.pdf is done
# Parsing file Expressive English Text-to-Speech Synthesis System_7.pdf is done
# Parsing file Face Recognition in Videos.pdf is done
# Parsing file FASHION RECOMMENDATION AND_DESIGN USING MACHINE LEARNING.pdf is done
# Parsing file Fast and efficient compression method for real time systems_41.pdf is done
# Parsing file final BE report.pdf is done
# Parsing file final BE report1.pdf is done
# Parsing file final Be Report2.pdf is done
# Parsing file Final full report.pdf is done
# Parsing file Final gts.pdf is done
# Parsing file Final Report(Group No 95).pdf is done
# Parsing file FOOD QUALITY INSPECTION USING_COMPUTER VISION.pdf is done
# Parsing file Galaxy Morphology Prediction using Convolutional_Neural Networks_64.pdf is done
# Parsing file Generic Replicator Framework.pdf is done
# Parsing file Generic SDK for zephyr OS to connect AWS IoT cloud.pdf is done
# Parsing file Generic User Activity Analysis And Prediction_34.pdf is done
# Parsing file Generic_Traffic_Shaper_19.pdf is done
# Parsing file GEO-ENABLED PROPERTY TAX.pdf is done
# Parsing file GESTURE AWARE INTERACTIVE_PRESENTATION SYSTEM.pdf is done
# Parsing file GPS SUPPORTED CITY BUS TRACKING AND TRIP PLANNER_53.pdf is done
# Parsing file GPU Framework Utilities Group_id_80.pdf is done
# Parsing file Group 12 Final Report.pdf is done
# Parsing file Group 40 PICT BE E&TC - Video Game Programming (1).pdf is done
# Parsing file Group 42.pdf is done
# Parsing file Group 81.pdf is done
# Parsing file Group 88.pdf is done
# Parsing file GROUP NO 83 (1).pdf is done
# Parsing file Group no 87.pdf is done
# Parsing file GROUP no 94 _ CAN PROTOCOL_.pdf is done
# Parsing file group no. 84.pdf is done
# Parsing file group no.55.pdf is done
# Parsing file GROUP NO.69_SIGN_LANGUAGE_REPORT.pdf is done
# Parsing file Group no.82.pdf is done
# Parsing file Group no_36_BE Final report.pdf is done
# Parsing file Group.No.7_InternetTvGadget_report.pdf is done
# Parsing file Group.No_01.pdf is done
# Parsing file Group.No_02.pdf is done
# Parsing file Group.No_03.pdf is done
# Parsing file Group.No_05.pdf is done
# Parsing file Group.No_06.pdf is done
# Parsing file Group.No_09.pdf is done
# Parsing file Group.No_10.pdf is done
# Parsing file Group.No_100.pdf is done
# Parsing file Group.No_101.pdf is done
# Parsing file Group.No_103.pdf is done
# Parsing file Group.No_104.pdf is done
# Parsing file Group.No_105.pdf is done
# Parsing file Group.No_106.pdf is done
# Parsing file Group.No_107.pdf is done
# Parsing file Group.No_11.pdf is done
# Parsing file Group.No_110.pdf is done
# Parsing file Group.No_14.pdf is done
# Parsing file Group.No_15.pdf is done
# Parsing file Group.No_16.pdf is done
# Parsing file Group.No_17.pdf is done
# Parsing file Group.No_18.pdf is done
# Parsing file Group.No_19.pdf is done
# Parsing file Group.No_20.pdf is done
# Parsing file Group.No_21.pdf is done
# Parsing file Group.No_22.pdf is done
# Parsing file Group.No_23.pdf is done
# Parsing file Group.No_24.pdf is done
# Parsing file Group.No_25.pdf is done
# Parsing file Group.No_26.pdf is done
# Parsing file Group.No_27.pdf is done
# Parsing file Group.No_28.pdf is done
# Parsing file Group.No_29.pdf is done
# Parsing file Group.No_30.pdf is done
# Parsing file Group.No_32.pdf is done
# Parsing file Group.No_33.pdf is done
# Parsing file Group.No_34.pdf is done
# Parsing file Group.No_35.pdf is done
# Parsing file Group.No_36.pdf is done
# Parsing file Group.No_37.pdf is done
# Parsing file Group.No_38.pdf is done
# Parsing file Group.No_39.pdf is done
# Parsing file Group.No_40.pdf is done
# Parsing file Group.No_42.pdf is done
# Parsing file Group.No_43.pdf is done
# Parsing file Group.No_44.pdf is done
# Parsing file Group.No_45.pdf is done
# Parsing file Group.No_46.pdf is done
# Parsing file Group.No_47.pdf is done
# Parsing file Group.No_49.pdf is done
# Parsing file Group.No_50.pdf is done
# Parsing file Group.No_51.pdf is done
# Parsing file Group.No_53.pdf is done
# Parsing file Group.No_56.pdf is done
# Parsing file Group.No_57.pdf is done
# Parsing file Group.No_58.pdf is done
# Parsing file Group.No_59.PDF is done
# Parsing file Group.No_60.pdf is done
# Parsing file Group.No_61.pdf is done
# Parsing file Group.No_62.pdf is done
# Parsing file Group.No_63.pdf is done
# Parsing file Group.No_64.pdf is done
# Parsing file Group.No_65.pdf is done
# Parsing file Group.No_66.pdf is done
# Parsing file Group.No_67.pdf is done
# Parsing file Group.No_68.pdf is done
# Parsing file Group.No_69.pdf is done
# Parsing file Group.No_70.pdf is done
# Parsing file Group.No_71.pdf is done
# Parsing file Group.No_72.pdf is done
# Parsing file Group.No_73.pdf is done
# Parsing file Group.No_74.pdf is done
# Parsing file Group.No_75.pdf is done
# Parsing file Group.No_76.pdf is done
# Parsing file Group.No_77.pdf is done
# Parsing file Group.No_81.pdf is done
# Parsing file Group.No_83.pdf is done
# Parsing file Group.No_85.pdf is done
# Parsing file Group.No_86.pdf is done
# Parsing file Group.No_89.pdf is done
# Parsing file Group.No_90.pdf is done
# Parsing file Group.No_91.pdf is done
# Parsing file Group.No_93.pdf is done
# Parsing file Group.No_94.pdf is done
# Parsing file Group.No_95.pdf is done
# Parsing file Group.No_98.pdf is done
# Parsing file Group.No_99.pdf is done
# Parsing file group32.pdf is done
# Parsing file Hand Gesture Recognition System using Microsoft Kinect_for a better Human Computer Interaction_60.pdf is done
# Parsing file HATE SPEECH DETECTION ON TWITTER_USING SENTIMENT ANALYSIS.pdf is done
# Parsing file HIRING DECISION SUPPORT SYSTEM_13.pdf is done
# Parsing file HPC clodburst using docker_42.pdf is done
# Parsing file Human Action Recognition System.pdf is done
# Parsing file Human detection and gender classification using Machine Learning based approach_10.pdf is done
# Parsing file Image Generation in the Style of Artists Using Deep Learning_65.pdf is done
# Parsing file IMAGE GENERATION OF HUMAN FACES FROM_TEXT DESCRIPTION USING GENERATIVE_ADVERSARIAL NETWORKS.pdf is done
# Parsing file Image_Search_Report25.pdf is done
# Parsing file implementation of HPCG using MPI and GPUs_7.pdf is done
# Parsing file Implementation of QoE-QoS in SDN_52.pdf is done
# Parsing file Improving performance of Virtual Machines by Virtio Bridge Bypass for PCI devices_69.pdf is done
# Parsing file Indoor Location based Services using Bluetooth Low Energy_47.pdf is done
# Parsing file Indoor Positioning system with BLE beacons using voronoi mapping.pdf is done
# Parsing file INSIDER THREAT DETECTION AND_ADAPTIVE TWO FACTOR_AUTHENTICATION SYSTEM FOR CLOUD_COMPUTING BY ANALYZING SYSTEM_LOGS.pdf is done
# Parsing file Integrated File Viewer_5.pdf is done
# Parsing file Integration of DeepLearning4j with Apache Apex framework_60.pdf is done
# Parsing file INTELLIGENT CYBER SECURITY SYSTEM.pdf is done
# Parsing file INTELLIGENT FINANCIAL PORTFOLIO.pdf is done
# Parsing file Intelligent Holiday Planner.pdf is done
# Parsing file Intelligent Recruitment Assistant_33.pdf is done
# Parsing file INTELLIGENT TOLL AUTOMATION SYSTEM_50.pdf is done
# Parsing file Intelligent transportation system_71.pdf is done
# Parsing file IntelligentAssistant.pdf is done
# Parsing file Interactive ChatBot_5.pdf is done
# Parsing file INTERACTIVE PHYSICAL EXPERIENCES FOR MICRO-LOCATION USING BEACON TECHNOLOGY_16.pdf is done
# Parsing file Interactive Store System_12.pdf is done
# Parsing file Interactive User Behaviour Analysis and_Recommendation System Using Web Log_Mining_15.pdf is done
# Parsing file IOT BASED BIKE BLACK BOX.pdf is done
# Parsing file IOT BASED HEALTH ALLIANCE HELP DESK_41.pdf is done
# Parsing file lazynotes_54.pdf is done
# Parsing file LEADER ELECTION ALGORITHM FOR WIRELESS_NETWORK_34.pdf is done
# Parsing file Live Backup of NFS using Network_Intelligence_44.pdf is done
# Parsing file Live process migration in mobil e env_63.pdf is done
# Parsing file Logistic Solutions for Multiple Scenarios using Wireless_Sensor Network_21.pdf is done
# Parsing file Log_structured_segment_cleaning_policy_49.pdf is done
# Parsing file M2M Communication_2.pdf is done
# Parsing file MACHINE LEARNING AGENT FOR GAME_DEVELOPMENT.pdf is done
# Parsing file Machine Learning Based Network Traffic Classification.pdf is done
# Parsing file MANAGING LAND OWNERSHIP USING_BLOCKCHAIN.pdf is done
# Parsing file Marathi translation using wsd concept_36.pdf is done
# Parsing file META DATA AND CONTENT BASED YOUTUBE_VIDEO TAG GENERATION.pdf is done
# Parsing file METAAPP A FRAMEWORK FOR INCOGNITO_MODE OF SMARTPHONE APPLICATIONS_25.pdf is done
# Parsing file Metering and Throttling for Remedy_Applications_76.pdf is done
# Parsing file MICRO VIDEO RECOMMENDATION_SYSTEM FOR CONTENT WRITER.pdf is done
# Parsing file Multi-document Abstractive Summarization_1.pdf is done
# Parsing file Multikeyword ranked search over encrypted data.pdf is done
# Parsing file Music Discovery Using Content Based Paradigms.pdf is done
# Parsing file N-SCALAR.pdf is done
# Parsing file Natural Language Description of Videos_46.pdf is done
# Parsing file negative news no more_42.pdf is done
# Parsing file NETWORK EDGE COMPUTING DEVICE_35.pdf is done
# Parsing file NETWORK MONITOR THROUGH ARM PROCESSOR_22.pdf is done
# Parsing file NETWORK MONITORING TOOL_45.pdf is done
# Parsing file NextGen_Router_17.pdf is done
# Parsing file Nfc-Health-Management_14.pdf is done
# Parsing file NOBODY PARKS HERE.pdf is done
# Parsing file NOTIFICATION SERVICE FOR CMDB.pdf is done
# Parsing file Novice Tourist Recommendation System.pdf is done
# Parsing file Object Based Visual Sentiment Analysis.pdf is done
# Parsing file OBSTACLE AVOIDANCE USING_REINFORCEMENT LEARNING.pdf is done
# Parsing file Ocr Pre-Processing.pdf is done
# Parsing file ONLINE REVIEW ANALYSIS.pdf is done
# Parsing file OpenAir Interface.pdf is done
# Parsing file OpenStack Resource Management Tool_ 33.pdf is done
# Parsing file OPTICAL COHERENCE_TOMOGRAPHY(OCT) REPORT_GENERATOR.pdf is done
# Parsing file Optimal Path-Finding in Virtual Reality_62.pdf is done
# Parsing file OptimisedDeliveryManagementSystemForE-Commerce_40.pdf is done
# Parsing file packet drop reduction by flow monitoring in sdn-nfv architecture group_id_24.pdf is done
# Parsing file Parallelization and Optimization of Image processing software using GPGPU with Cuda-c_70.pdf is done
# Parsing file PARALLELIZATION OF REGION GROWING IMAGE SEGMENTATION AL-_GORITHM FOR COLOUR IMAGE_40.pdf is done
# Parsing file PATTERN DETECTION AND_RECOGNITION SYSTEM FOR VEHICLES.pdf is done
# Parsing file PATTERN RECOGNITION IN IMAGES_58.pdf is done
# Parsing file pattern_detection_and_recognition_using_deep_learning_group_id_65.pdf is done
# Parsing file Personality Prediction System.pdf is done
# Parsing file PERSONALITY PREDICTION SYSTEM_USING TWITTER DATA.pdf is done
# Parsing file PHYSICAL WEB WITH VENDING MACHINE_77.pdf is done
# Parsing file PIXTALK_ PICTURE EXCHANGE COMMUNICATION_FOR AUTISM SPECTRUM DISORDER IN CHILDREN_USING MACHINE LEARNING.pdf is done
# Parsing file Plant Disease Detection Using Deep Learning Techniques.pdf is done
# Parsing file PLANT LEAF DISEASE IDENTIFICATION_39.pdf is done
# Parsing file PLATFORM FOR BUILDING ENTERPRISE_SOLUTIONS (WORKFLOW MANAGER).pdf is done
# Parsing file POLICE CONTROL ROOM RUNTIME_ANALYSIS.pdf is done
# Parsing file Porting Zephyr OS.pdf is done
# Parsing file Predicting_MyersBriggs_Personality_type.pdf is done
# Parsing file Predictive data analysis using recommendation techniques_and machine learning algorithms_10.pdf is done
# Parsing file Price Elasticity and Optimization_6.pdf is done
# Parsing file Privacy Preserving Multi-Keyword Ranked_Search Over Encrypted Cloud Data_56.pdf is done
# Parsing file Product Attribute Extraction And Comparator_26.pdf is done
# Parsing file Project Mycroft AI.pdf is done
# Parsing file Project Report Group No. 61.pdf is done
# Parsing file project report grp. no. 73.pdf is done
# Parsing file Project_Report_group51.pdf is done
# Parsing file PROVIDE CHATBOT FUNCTIONALITY IN BMC REMEDY AR SYSTEM PLATFORM.pdf is done
# Parsing file QA GENERATION APPLICATION USING NLP.pdf is done
# Parsing file QUERY BASED CAR MAKE AND MODEL_RECOGNITION SYSTEM USING DEEP_LEARNING.pdf is done
# Parsing file Question Pair Similarity and Text Summarization.pdf is done
# Parsing file Quick Learning Tool.pdf is done
# Parsing file RE-ADMISSION RISK PREDICTION FOR_HEART ATTACK.pdf is done
# Parsing file Re-Sequencing of Associated News Articles in a Feed Using_Sentiment Analysis_28.pdf is done
# Parsing file Real Time Image Description using Deep Learning.pdf is done
# Parsing file Real Time Web Analytics_59.pdf is done
# Parsing file Real Time Web Based Supervisory Control and Data Acquisition_32.pdf is done
# Parsing file RealTimeVehicleTrackingSystem_groupid_11.pdf is done
# Parsing file REBRACE _ AN INTELLIGENT SOLUTION FOR_SUPPORT HELPDESK AUTOMATION_20.pdf is done
# Parsing file Recommendation of crop and yield prediction_based on Multiple Parameters using Artificial_Neural Network.pdf is done
# Parsing file RECOMMENDATION USING CONTENT_BASED IMAGE RETRIEVAL.pdf is done
# Parsing file REPORT _GROUP_NO_45.pdf is done
# Parsing file Report-Group-6.pdf is done
# Parsing file Report-Group-71.pdf is done
# Parsing file report-groupno-47.pdf is done
# Parsing file Report_Final_zip_9.pdf is done
# Parsing file Resume analysis through machine learning_43.pdf is done
# Parsing file Retail_Analytics_61.pdf is done
# Parsing file Retroactive Funnel Analysis_53.pdf is done
# Parsing file RMI_Based_Custom_Adapter_8.pdf is done
# Parsing file Robust Speaker Recognition System for  online authentication and real-time verification.pdf is done
# Parsing file RouterReinforcementwithOpenWrtandCloud_3.pdf is done
# Parsing file SALES ORDER PROCESSING USING SAP_52.pdf is done
# Parsing file SCRUTINIZING BEHAVIOUR OF VM COMMUNICATION.pdf is done
# Parsing file Security Enhancement in Vehicular System with GPS and Motion Detection_76.pdf is done
# Parsing file SECURITY IN IOT_23.pdf is done
# Parsing file Sensor and reservation based interconnected parking system_36.pdf is done
# Parsing file SENTIMENT ANALYSIS ON TWITTER JDATA_74.pdf is done
# Parsing file SIGN LANGUAGE RECOGNITION.pdf is done
# Parsing file SIMULATOR FOR BMC BLADELOGIC SERVER_AUTOMATION_35.pdf is done
# Parsing file SISA_ SECURING IMAGES USING_SELECTIVE ALTERATION.pdf is done
# Parsing file SMART BUSINESS CONTINUITY APPLICATION.pdf is done
# Parsing file SMART CITY GARBAGE CAN_16.pdf is done
# Parsing file SMART ROOM FOR ELDERLY PEOPLE_6.pdf is done
# Parsing file Smart Room For Elderly Person_6.pdf is done
# Parsing file SMART STUDY GUIDE USING MACHINE_LEARNING.pdf is done
# Parsing file Smart Surveillance System_71.pdf is done
# Parsing file Smart virtual Assistant_31.pdf is done
# Parsing file Smart_Surveillance System_49.pdf is done
# Parsing file Social Impact Poll Generation System from tweets_50.pdf is done
# Parsing file SOFTWARE GPU UTILITIES_32.pdf is done
# Parsing file Speech and Speaker Recognition_for Home Security System.pdf is done
# Parsing file Stock Prediction Using Technical Analysis.pdf is done
# Parsing file SUPPLY CHAIN MANAGEMENT FOR AIRLINES_USING SALESFORCE(CLOUD)_43.pdf is done
# Parsing file SUPPLY CHAIN MANAGEMENT FOR_AUTOMOBILE INDUSTRY.pdf is done
# Parsing file Suspect Analysis using Machine Learning.pdf is done
# Parsing file System To Guide Visually Impaired People_47.pdf is done
# Parsing file TAG SCANNER CUM PRICE_COMPARISION FOR FASHION_PRODUCTS_13.pdf is done
# Parsing file Telephysiotherapy_20.pdf is done
# Parsing file Text Analysis for Indian Literature.pdf is done
# Parsing file Text Mining Algorithms For Assessment of Answersheets.pdf is done
# Parsing file Text summarization using extractive approach based on latent semantic analysis_04.pdf is done
# Parsing file TEXT SUMMARIZATION_USING EXTRACTIVE APPROACH BASED ON LATENT SEMANTIC ANALYSIS_18.pdf is done
# Parsing file Text to Image Generation.pdf is done
# Parsing file TEXT TO IMAGE SYNTHESIS IN FASHION.pdf is done
# Parsing file TRANSACTION MONITORING IN PUBLIC_WELFARE PROJECTS USING SMART_CONTRACTS.pdf is done
# Parsing file Transparent Distributed Computing for CUDA_24.pdf is done
# Parsing file UCAN-Unified Communication for Assisting Novice.pdf is done
# Parsing file USE OF COGNITIVE TECHNOLOGIES TO AID_DECISION MAKING IN THE INDIAN_JUDICIARY.pdf is done
# Parsing file User Application for Shop Floor Automation using Data Analytics_14.pdf is done
# Parsing file vCom-Volunteer Computing for High Performance_26.pdf is done
# Parsing file VEHICULAR SECURITY SYSTEM_3.pdf is done
# Parsing file VHDX File Recovery_54.pdf is done
# Parsing file VIDEO BASED TRAFFIC CONTROL SYSTEM_77.pdf is done
# Parsing file Video Summarization using clustering techniques.pdf is done
# Parsing file Video Summarization_31.pdf is done
# Parsing file Virtual Arts Gallery_75.pdf is done
# Parsing file Virtual Lab for Electronics_29.pdf is done
# Parsing file VIRTUAL MACHINE COMMUNICATION_ANALYSIS.pdf is done
# Parsing file Visual Question Answering Using Deep_Learning_30.pdf is done
# Parsing file Visualization As A Sevice_11.pdf is done
# Parsing file VISUALLY IMPAIRED ASSISTANT SYSTEM.pdf is done
# Parsing file Volunteer Automation For NGO_79.pdf is done
# Parsing file Web_Vulnerability Scanner.pdf is done
# Parsing file ___BREAST CANCER DETECTION AND_DIAGNOSIS USING MACHINE LEARNING___.pdf is done
# Total files: 419
# Discarded files: 0
# Wall time: 28min 19s
