# %% [markdown]
# # File parsing and Keyword Extraction (Phase 1)

# %% [markdown]
# #### 1) Input:
#    Raw documents stored in folder (reports).
# #### 2) Output:
#    dataset.json file
# #### 3) Algorithm
#    a) Read pdf files and extract abstract and project implementation part using some if-else.<br>
#    b) Use text preprocessing techniques to filter text. <br>
#    c) Using rake-nltk to extract keywords using textrank algorithm.<br>
#    d) Create dictionary and dump it in file named dataset.json

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
import nltk
from nltk import word_tokenize
import string
import re
from nltk.stem import WordNetLemmatizer
import numpy as np
import math
import os
from itertools import zip_longest
import json
import pandas as pd
import time
from gensim.summarization.keywords import keywords
from rake_nltk import Rake, Metric
from nltk.corpus import stopwords
from multiprocessing import Pool

# %%
reports = "reports/comp"
abstracts = "abstract/"
models = "model/"

# %%
processed_dict = {}
clustered_keywords = {}

# %%
def get_title_project(text):
    arr = []
    i = 0
    for elem in text.split("\n"):
        if i == 0:
            i += 1
            continue
        if elem == "":
            continue
        if "savitribai phule" not in elem.lower():
            arr.append(elem)
        elif "savitribai phule" in elem.lower():
            return " ".join(arr)
    
    if len(arr) == 0:
        return ""
    return " ".join(arr)

# %%
def get_abstract_project(text):
    arr = text.split("\n")
    del arr[0]
    return " ".join(arr)

# %%
def convert_to_float(x):
    try:
        return np.float64(x)
    except:
        return 0

# %%
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()
    implementation_found = False
    abstract_found = False
    introduction_found = False
    chapter_found = -1
    abstract_page_no = 3

    new_dict = {}

    for pageNo, page in enumerate(PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True)):
        interpreter.process_page(page)
        data = retstr.getvalue()
        if pageNo == 0:
            new_dict["title"] = get_title_project(data)
        
        if pageNo == abstract_page_no:
            if "acknowledgement" in data.lower():
                abstract_page_no += 1
            else:
                abstract_found = True
                new_dict["abstract"] = get_abstract_project(data)
      
        if "references" in data.lower() and implementation_found == True:
            break
            
        if introduction_found == True:
            if "implementation" in new_dict:
                new_dict["implementation"] += data
            else:
                new_dict["implementation"] = data 
        
        if "introduction" in data.lower() and "chapter" in data.lower() and abstract_found == True:
            introduction_found = True
 

        data = ""
        retstr.truncate(0)
        retstr.seek(0)
        
    fp.close()
    device.close()
    retstr.close()
    return new_dict

# %%
def init():
    with open("long_stopwords.txt", "r") as fp:
        stopwords_long = fp.read().split("\n")
    common_stopwords = list(stopwords.words("english"))
    stopwords_list = list(set(stopwords_long + common_stopwords))
    punctuations = list(str(string.punctuation))
    return (stopwords_list, punctuations)

# %%
stopwords_list, punctuations = init()
rake = Rake(stopwords=stopwords_list, punctuations=punctuations, max_length=100000, ranking_metric=Metric.DEGREE_TO_FREQUENCY_RATIO)

# %%
def clean(text):
    text = text.lower()
    printable = set(string.printable)
    text = filter(lambda x: x in printable, text) #filter funny characters, if any.
    return "".join(list(text))

# %%
def parse_doc(filename):
    
    try:
        print("Parsing file: {} started".format(filename))
        processed_dict[filename] = convert_pdf_to_txt(reports + "/" + filename)
        #nltk.download('punkt')
    except:
        print("Error in parsing file {}".format(filename))
        
    
    try:
        text = clean(processed_dict[filename]["abstract"] + processed_dict[filename]["implementation"])
        rake.extract_keywords_from_text(text)
        processed_dict[filename]["keywords"] = dict(rake.get_ranked_phrases_with_scores())
        print("Parsing file: {} completed".format(filename))
    except:
        print("Keyerror implementation in file {}".format(filename))
    
    return processed_dict

# %%
# %%time
def main():
    
    print("\n==============Welcome to phase 1============\n")
    
    file_array = os.listdir(reports)
    pool = Pool(processes=4)
    processed_dict = pool.map(parse_doc, file_array)
    pool.close()
    pool.join()
    
    json_string = json.dumps(processed_dict)
    
    with open("dataset.json", "w") as fp:
        fp.write(json_string)
    fp.close()

    print("\n===========Phase 1 ended==========\n")
# Out:
# CPU times: user 9 µs, sys: 0 ns, total: 9 µs
# Wall time: 15.5 µs

# %%
if __name__ == "__main__":
    main()
# Out:
# ==============Welcome to phase 1============
#
# Parsing file: User Application for Shop Floor Automation using Data Analytics_14.pdf started
# Parsing file: Text Mining Algorithms For Assessment of Answersheets.pdf started
# Parsing file: Disease prediction using machine learning_55.pdf started
# Parsing file: lazynotes_54.pdf started
# Parsing file: Text Mining Algorithms For Assessment of Answersheets.pdf completed
# Parsing file: HPC clodburst using docker_42.pdf started
# Parsing file: User Application for Shop Floor Automation using Data Analytics_14.pdf completed
# Parsing file: SCRUTINIZING BEHAVIOUR OF VM COMMUNICATION.pdf started
# Parsing file: lazynotes_54.pdf completed
# Parsing file: Machine Learning Based Network Traffic Classification.pdf started
# Parsing file: HPC clodburst using docker_42.pdf completed
# Parsing file: Stock Prediction Using Technical Analysis.pdf started
# Parsing file: SCRUTINIZING BEHAVIOUR OF VM COMMUNICATION.pdf completed
# Parsing file: Plant Disease Detection Using Deep Learning Techniques.pdf started
# Parsing file: Machine Learning Based Network Traffic Classification.pdf completed
# Parsing file: SUPPLY CHAIN MANAGEMENT FOR_AUTOMOBILE INDUSTRY.pdf started
# Parsing file: Stock Prediction Using Technical Analysis.pdf completed
# Parsing file: INTELLIGENT FINANCIAL PORTFOLIO.pdf started
# Parsing file: SUPPLY CHAIN MANAGEMENT FOR_AUTOMOBILE INDUSTRY.pdf completed
# Parsing file: Conditional GIF Generation Using GANS.pdf started
# Parsing file: Plant Disease Detection Using Deep Learning Techniques.pdf completed
# Parsing file: CONTEXTUAL RECOMMENDATION AND_SUMMARIZATION OF ENTERPRISE_COMMUNICATION.pdf started
# Parsing file: Conditional GIF Generation Using GANS.pdf completed
# Parsing file: Intelligent Holiday Planner.pdf started
# Parsing file: INTELLIGENT FINANCIAL PORTFOLIO.pdf completed
# Parsing file: ELECTION RESULT PREDICTION USING_SENTIMENTAL ANALYSIS ON TWITTER DATA.pdf started
# Parsing file: CONTEXTUAL RECOMMENDATION AND_SUMMARIZATION OF ENTERPRISE_COMMUNICATION.pdf completed
# Parsing file: Speech and Speaker Recognition_for Home Security System.pdf started
# Parsing file: Disease prediction using machine learning_55.pdf completed
# Parsing file: POLICE CONTROL ROOM RUNTIME_ANALYSIS.pdf started
# Parsing file: ELECTION RESULT PREDICTION USING_SENTIMENTAL ANALYSIS ON TWITTER DATA.pdf completed
# Parsing file: COMPREHENSIVE DEVELOPER ASSISTANT_(CODA).pdf started
# Parsing file: POLICE CONTROL ROOM RUNTIME_ANALYSIS.pdf completed
# Parsing file: ___BREAST CANCER DETECTION AND_DIAGNOSIS USING MACHINE LEARNING___.pdf started
# Parsing file: COMPREHENSIVE DEVELOPER ASSISTANT_(CODA).pdf completed
# Parsing file: SISA_ SECURING IMAGES USING_SELECTIVE ALTERATION.pdf started
# Parsing file: Speech and Speaker Recognition_for Home Security System.pdf completed
# Parsing file: Chatbot for automated customer support.pdf started
# Parsing file: Intelligent Holiday Planner.pdf completed
# Parsing file: IOT BASED BIKE BLACK BOX.pdf started
# Parsing file: ___BREAST CANCER DETECTION AND_DIAGNOSIS USING MACHINE LEARNING___.pdf completed
# Parsing file: Report_Final_zip_9.pdf started
# Parsing file: IOT BASED BIKE BLACK BOX.pdf completed
# Parsing file: MACHINE LEARNING AGENT FOR GAME_DEVELOPMENT.pdf started
# Parsing file: Chatbot for automated customer support.pdf completed
# Parsing file: Disease Diagnosis Using Nadi Parikshan_44.pdf started
# Parsing file: SISA_ SECURING IMAGES USING_SELECTIVE ALTERATION.pdf completed
# Parsing file: REBRACE _ AN INTELLIGENT SOLUTION FOR_SUPPORT HELPDESK AUTOMATION_20.pdf started
# Parsing file: MACHINE LEARNING AGENT FOR GAME_DEVELOPMENT.pdf completed
# Parsing file: Automatic SQL Query Formation using NLP.pdf started
# Parsing file: Report_Final_zip_9.pdf completed
# Parsing file: Crop yield estimation using Data mining techniques..pdf started
# Parsing file: Disease Diagnosis Using Nadi Parikshan_44.pdf completed
# Parsing file: PLATFORM FOR BUILDING ENTERPRISE_SOLUTIONS (WORKFLOW MANAGER).pdf started
# Parsing file: Automatic SQL Query Formation using NLP.pdf completed
# Parsing file: Context aware book recommendation system_27.pdf started
# Parsing file: REBRACE _ AN INTELLIGENT SOLUTION FOR_SUPPORT HELPDESK AUTOMATION_20.pdf completed
# Parsing file: CONSTRUCT 3D COMPUTER OBJECTS_FROM MULTIPLE VIEWS.pdf started
# Parsing file: Crop yield estimation using Data mining techniques..pdf completed
# Parsing file: AI- ASSISTED POTENTIAL HEALTH RISK_PREDICTOR.pdf started
# Parsing file: PLATFORM FOR BUILDING ENTERPRISE_SOLUTIONS (WORKFLOW MANAGER).pdf completed
# Parsing file: FASHION RECOMMENDATION AND_DESIGN USING MACHINE LEARNING.pdf started
# Parsing file: CONSTRUCT 3D COMPUTER OBJECTS_FROM MULTIPLE VIEWS.pdf completed
# Parsing file: Question Pair Similarity and Text Summarization.pdf started
# Parsing file: AI- ASSISTED POTENTIAL HEALTH RISK_PREDICTOR.pdf completed
# Parsing file: E-GLOVE_ A HEALTH MONITORING_SYSTEM USING WEARABLE COMPUTING,_IoT AND DATA MINING.pdf started
# Parsing file: FASHION RECOMMENDATION AND_DESIGN USING MACHINE LEARNING.pdf completed
# Parsing file: Object Based Visual Sentiment Analysis.pdf started
# Parsing file: Context aware book recommendation system_27.pdf completed
# Parsing file: E-Care-Android Application For Health Monitoring_73.pdf started
# Parsing file: E-GLOVE_ A HEALTH MONITORING_SYSTEM USING WEARABLE COMPUTING,_IoT AND DATA MINING.pdf completed
# Parsing file: BE_PROJECT_REPORT_FORMAT_TERM_II_LATEX_FILE_68.pdf started
# Parsing file: Question Pair Similarity and Text Summarization.pdf completed
# Parsing file: DRONE DROID_58.pdf started
# Parsing file: Object Based Visual Sentiment Analysis.pdf completed
# Parsing file: META DATA AND CONTENT BASED YOUTUBE_VIDEO TAG GENERATION.pdf started
# Parsing file: E-Care-Android Application For Health Monitoring_73.pdf completed
# Parsing file: Face Recognition in Videos.pdf started
# Parsing file: BE_PROJECT_REPORT_FORMAT_TERM_II_LATEX_FILE_68.pdf completed
# Parsing file: A CRYPTOSYSTEM FOR ENCRYPTION OF_DATA USING IMAGES FOR KEY_GENERATION.pdf started
# Parsing file: META DATA AND CONTENT BASED YOUTUBE_VIDEO TAG GENERATION.pdf completed
# Parsing file: PATTERN DETECTION AND_RECOGNITION SYSTEM FOR VEHICLES.pdf started
# Parsing file: DRONE DROID_58.pdf completed
# Parsing file: AUTOMATED GLAUCOMA DETECTION.pdf started
# Parsing file: Face Recognition in Videos.pdf completed
# Parsing file: Dynamic Forms - UI UX.pdf started
# Parsing file: A CRYPTOSYSTEM FOR ENCRYPTION OF_DATA USING IMAGES FOR KEY_GENERATION.pdf completed
# Parsing file: SIMULATOR FOR BMC BLADELOGIC SERVER_AUTOMATION_35.pdf started
# Parsing file: Dynamic Forms - UI UX.pdf completed
# Parsing file: self learning cognitive system using large scale neural network_21.pdf started
# Parsing file: AUTOMATED GLAUCOMA DETECTION.pdf completed
# Parsing file: Suspect Analysis using Machine Learning.pdf started
# Parsing file: PATTERN DETECTION AND_RECOGNITION SYSTEM FOR VEHICLES.pdf completed
# Parsing file: ANALYSIS OF PRIVACY POLICIES VIA_MACHINE LEARNING.pdf started
# Parsing file: SIMULATOR FOR BMC BLADELOGIC SERVER_AUTOMATION_35.pdf completed
# Parsing file: A fast distributed key-value store based on_the RAFT protocol and Judy arrays_37.pdf started
# Parsing file: ANALYSIS OF PRIVACY POLICIES VIA_MACHINE LEARNING.pdf completed
# Parsing file: Human detection and gender classification using Machine Learning based approach_10.pdf started
# Parsing file: A fast distributed key-value store based on_the RAFT protocol and Judy arrays_37.pdf completed
# Parsing file: VEHICULAR SECURITY SYSTEM_3.pdf started
# Parsing file: Suspect Analysis using Machine Learning.pdf completed
# Parsing file: Real Time Web Analytics_59.pdf started
# Parsing file: Human detection and gender classification using Machine Learning based approach_10.pdf completed
# Parsing file: INTELLIGENT TOLL AUTOMATION SYSTEM_50.pdf started
# Parsing file: Real Time Web Analytics_59.pdf completed
# Parsing file: Galaxy Morphology Prediction using Convolutional_Neural Networks_64.pdf started
# Parsing file: VEHICULAR SECURITY SYSTEM_3.pdf completed
# Parsing file: Differentiating Between Attacker And Legitimate VM.pdf started
# Parsing file: Galaxy Morphology Prediction using Convolutional_Neural Networks_64.pdf completed
# Parsing file: Robust Speaker Recognition System for  online authentication and real-time verification.pdf started
# Parsing file: self learning cognitive system using large scale neural network_21.pdf completed
# Parsing file: OpenAir Interface.pdf started
# Parsing file: Differentiating Between Attacker And Legitimate VM.pdf completed
# Parsing file: APPLICATION TO DETERMINE THE SAFEST ROUTE USING CRIME JANALYSIS VIA DECISION TREE JALGORITHM_78.pdf started
# Parsing file: INTELLIGENT TOLL AUTOMATION SYSTEM_50.pdf completed
# Parsing file: Exploring alternative approaches to control forwarding path of packets in virtual networks_4.pdf started
# Parsing file: OpenAir Interface.pdf completed
# Parsing file: Predicting_MyersBriggs_Personality_type.pdf started
# Parsing file: Robust Speaker Recognition System for  online authentication and real-time verification.pdf completed
# Parsing file: ONLINE REVIEW ANALYSIS.pdf started
# Parsing file: APPLICATION TO DETERMINE THE SAFEST ROUTE USING CRIME JANALYSIS VIA DECISION TREE JALGORITHM_78.pdf completed
# Parsing file: Android Malware Detection Using Machine Learning_67.pdf started
# Parsing file: Exploring alternative approaches to control forwarding path of packets in virtual networks_4.pdf completed
# Parsing file: USE OF COGNITIVE TECHNOLOGIES TO AID_DECISION MAKING IN THE INDIAN_JUDICIARY.pdf started
# Parsing file: ONLINE REVIEW ANALYSIS.pdf completed
# Parsing file: SMART STUDY GUIDE USING MACHINE_LEARNING.pdf started
# Parsing file: Android Malware Detection Using Machine Learning_67.pdf completed
# Parsing file: OptimisedDeliveryManagementSystemForE-Commerce_40.pdf started
# Parsing file: Predicting_MyersBriggs_Personality_type.pdf completed
# Parsing file: EFFICIENT DIABETES RISK ASSESSMENT IN_PATIENTS USING MACHINE LEARNING_ALGORITHMS.pdf started
# Parsing file: SMART STUDY GUIDE USING MACHINE_LEARNING.pdf completed
# Parsing file: Detection Of Diabetic Retinopathy Detection Using Computer Vision.pdf started
# Parsing file: OptimisedDeliveryManagementSystemForE-Commerce_40.pdf completed
# Parsing file: Interactive ChatBot_5.pdf started
# Parsing file: EFFICIENT DIABETES RISK ASSESSMENT IN_PATIENTS USING MACHINE LEARNING_ALGORITHMS.pdf completed
# Parsing file: COMPLIANCE ENGINE FOR DATABASES.pdf started
# Parsing file: USE OF COGNITIVE TECHNOLOGIES TO AID_DECISION MAKING IN THE INDIAN_JUDICIARY.pdf completed
# Parsing file: GEO-ENABLED PROPERTY TAX.pdf started
# Parsing file: COMPLIANCE ENGINE FOR DATABASES.pdf completed
# Parsing file: EMOTION BASED MUSIC PLAYER.pdf started
# Parsing file: Interactive ChatBot_5.pdf completed
# Parsing file: SECURITY IN IOT_23.pdf started
# Parsing file: Detection Of Diabetic Retinopathy Detection Using Computer Vision.pdf completed
# Parsing file: FOOD QUALITY INSPECTION USING_COMPUTER VISION.pdf started
# Parsing file: GEO-ENABLED PROPERTY TAX.pdf completed
# Parsing file: Real Time Image Description using Deep Learning.pdf started
# Parsing file: SECURITY IN IOT_23.pdf completed
# Parsing file: Intelligent transportation system_71.pdf started
# Parsing file: FOOD QUALITY INSPECTION USING_COMPUTER VISION.pdf completed
# Parsing file: Intelligent Recruitment Assistant_33.pdf started
# Parsing file: EMOTION BASED MUSIC PLAYER.pdf completed
# Parsing file: Product Attribute Extraction And Comparator_26.pdf started
# Parsing file: Real Time Image Description using Deep Learning.pdf completed
# Parsing file: QUERY BASED CAR MAKE AND MODEL_RECOGNITION SYSTEM USING DEEP_LEARNING.pdf started
# Parsing file: Intelligent transportation system_71.pdf completed
# Parsing file: Metering and Throttling for Remedy_Applications_76.pdf started
# Parsing file: Product Attribute Extraction And Comparator_26.pdf completed
# Parsing file: Expressive English Text-to-Speech Synthesis System_7.pdf started
# Parsing file: Intelligent Recruitment Assistant_33.pdf completed
# Parsing file: Automatic Notification Bot Using Web JMining for Event Analysis_72.pdf started
# Parsing file: QUERY BASED CAR MAKE AND MODEL_RECOGNITION SYSTEM USING DEEP_LEARNING.pdf completed
# Parsing file: Interactive Store System_12.pdf started
# Parsing file: Metering and Throttling for Remedy_Applications_76.pdf completed
# Parsing file: NOTIFICATION SERVICE FOR CMDB.pdf started
# Parsing file: Automatic Notification Bot Using Web JMining for Event Analysis_72.pdf completed
# Parsing file: CONVERSION OF VIDEO CONTAINING SIGN_LANGUAGE TO TEXTUAL FORMAT.pdf started
# Parsing file: Expressive English Text-to-Speech Synthesis System_7.pdf completed
# Parsing file: Recommendation of crop and yield prediction_based on Multiple Parameters using Artificial_Neural Network.pdf started
# Parsing file: NOTIFICATION SERVICE FOR CMDB.pdf completed
# Parsing file: Text Analysis for Indian Literature.pdf started
# Parsing file: CONVERSION OF VIDEO CONTAINING SIGN_LANGUAGE TO TEXTUAL FORMAT.pdf completed
# Parsing file: Virtual Arts Gallery_75.pdf started
# Parsing file: Interactive Store System_12.pdf completed
# Parsing file: Visualization As A Sevice_11.pdf started
# Keyerror implementation in file Recommendation of crop and yield prediction_based on Multiple Parameters using Artificial_Neural Network.pdf
# Parsing file: Distracted_Driver_Detection_ Using_Deep_Learning.pdf started
# Parsing file: Visualization As A Sevice_11.pdf completed
# Parsing file: PROVIDE CHATBOT FUNCTIONALITY IN BMC REMEDY AR SYSTEM PLATFORM.pdf started
# Parsing file: Virtual Arts Gallery_75.pdf completed
# Parsing file: A SYSTEM FOR LANGUAGE TRANSLATION.pdf started
# Parsing file: Distracted_Driver_Detection_ Using_Deep_Learning.pdf completed
# Parsing file: Text to Image Generation.pdf started
# Parsing file: Text Analysis for Indian Literature.pdf completed
# Parsing file: IOT BASED HEALTH ALLIANCE HELP DESK_41.pdf started
# Parsing file: A SYSTEM FOR LANGUAGE TRANSLATION.pdf completed
# Parsing file: Resume analysis through machine learning_43.pdf started
# Parsing file: PROVIDE CHATBOT FUNCTIONALITY IN BMC REMEDY AR SYSTEM PLATFORM.pdf completed
# Parsing file: IMAGE GENERATION OF HUMAN FACES FROM_TEXT DESCRIPTION USING GENERATIVE_ADVERSARIAL NETWORKS.pdf started
# Parsing file: Text to Image Generation.pdf completed
# Parsing file: VISUALLY IMPAIRED ASSISTANT SYSTEM.pdf started
# Parsing file: IOT BASED HEALTH ALLIANCE HELP DESK_41.pdf completed
# Parsing file: Classification of abstract images using machine learning_66.pdf started
# Parsing file: IMAGE GENERATION OF HUMAN FACES FROM_TEXT DESCRIPTION USING GENERATIVE_ADVERSARIAL NETWORKS.pdf completed
# Parsing file: System To Guide Visually Impaired People_47.pdf started
# Parsing file: VISUALLY IMPAIRED ASSISTANT SYSTEM.pdf completed
# Parsing file: Generic User Activity Analysis And Prediction_34.pdf started
# Parsing file: Resume analysis through machine learning_43.pdf completed
# Parsing file: 2D TO 3D IMAGE CONVERSION USING_MACHINE LEARNING APPROACH.pdf started
# Parsing file: Generic User Activity Analysis And Prediction_34.pdf completed
# Parsing file: Marathi translation using wsd concept_36.pdf started
# Parsing file: System To Guide Visually Impaired People_47.pdf completed
# Parsing file: Novice Tourist Recommendation System.pdf started
# Parsing file: 2D TO 3D IMAGE CONVERSION USING_MACHINE LEARNING APPROACH.pdf completed
# Parsing file: Emergency Blood Requirement system_48.pdf started
# Parsing file: Classification of abstract images using machine learning_66.pdf completed
# Parsing file: Article Classification and Recommendation system.pdf started
# Parsing file: Novice Tourist Recommendation System.pdf completed
# Parsing file: ENHANCED FRAMEWORK FOR TRUE_SIGHT NETWORK AUTOMATION.pdf started
# Parsing file: Marathi translation using wsd concept_36.pdf completed
# Parsing file: Biometric Based RTO License Checking_And Fine system.pdf started
# Parsing file: Emergency Blood Requirement system_48.pdf completed
# Parsing file: Multi-document Abstractive Summarization_1.pdf started
# Parsing file: ENHANCED FRAMEWORK FOR TRUE_SIGHT NETWORK AUTOMATION.pdf completed
# Parsing file: Video Summarization using clustering techniques.pdf started
# Parsing file: Article Classification and Recommendation system.pdf completed
# Parsing file: analyze online clickstream data to understand user intent and personalized ads_25.pdf started
# Parsing file: Biometric Based RTO License Checking_And Fine system.pdf completed
# Parsing file: Web_Vulnerability Scanner.pdf started
# Parsing file: Video Summarization using clustering techniques.pdf completed
# Parsing file: analyze online clickstream data to understand user intent and personalized ads_25.pdf completed
# Parsing file: MANAGING LAND OWNERSHIP USING_BLOCKCHAIN.pdf started
# Parsing file: Virtual Lab for Electronics_29.pdf started
# Parsing file: Multi-document Abstractive Summarization_1.pdf completed
# Parsing file: PHYSICAL WEB WITH VENDING MACHINE_77.pdf started
# Parsing file: Web_Vulnerability Scanner.pdf completed
# Parsing file: CONVERSION OF MARATHI TEXT TO_BRAILLE USING OPTICAL CHARACTER_RECOGNITION.pdf started
# Parsing file: Virtual Lab for Electronics_29.pdf completed
# Parsing file: AIR POLLUTION DETECTION WITH_NAVIGATION SYSTEM.pdf started
# Parsing file: PHYSICAL WEB WITH VENDING MACHINE_77.pdf completed
# Parsing file: Development of Intelligent automated indoor_navigator and assistance system.pdf started
# Parsing file: CONVERSION OF MARATHI TEXT TO_BRAILLE USING OPTICAL CHARACTER_RECOGNITION.pdf completed
# Parsing file: Creating server on android phone using NanoHTTPD.pdf started
# Parsing file: MANAGING LAND OWNERSHIP USING_BLOCKCHAIN.pdf completed
# Parsing file: Automated Sound Quality Enhancer Assistant.pdf started
# Parsing file: AIR POLLUTION DETECTION WITH_NAVIGATION SYSTEM.pdf completed
# Parsing file: AUTOMATED BRAKING TEST FOR_VEHICLE LICENSES.pdf started
# Parsing file: Automated Sound Quality Enhancer Assistant.pdf completed
# Parsing file: Disease Detection using ayurvedic pulse diagnosis.pdf started
# Parsing file: Creating server on android phone using NanoHTTPD.pdf completed
# Parsing file: Human Action Recognition System.pdf started
# Parsing file: Development of Intelligent automated indoor_navigator and assistance system.pdf completed
# Parsing file: Generic SDK for zephyr OS to connect AWS IoT cloud.pdf started
# Parsing file: AUTOMATED BRAKING TEST FOR_VEHICLE LICENSES.pdf completed
# Parsing file: NETWORK MONITORING TOOL_45.pdf started
# Parsing file: Human Action Recognition System.pdf completed
# Parsing file: Generic Replicator Framework.pdf started
# Parsing file: Generic SDK for zephyr OS to connect AWS IoT cloud.pdf completed
# Parsing file: AUTOMATED FINANCIAL PORTFOLIO BUILDING_57.pdf started
# Parsing file: Disease Detection using ayurvedic pulse diagnosis.pdf completed
# Parsing file: RECOMMENDATION USING CONTENT_BASED IMAGE RETRIEVAL.pdf started
# Parsing file: NETWORK MONITORING TOOL_45.pdf completed
# Parsing file: AUTO PAINTER_ TEXT TO IMAGE_SYNTHESIS.pdf started
# Parsing file: AUTOMATED FINANCIAL PORTFOLIO BUILDING_57.pdf completed
# Parsing file: HIRING DECISION SUPPORT SYSTEM_13.pdf started
# Parsing file: Generic Replicator Framework.pdf completed
# Parsing file: Porting Zephyr OS.pdf started
# Parsing file: AUTO PAINTER_ TEXT TO IMAGE_SYNTHESIS.pdf completed
# Parsing file: INSIDER THREAT DETECTION AND_ADAPTIVE TWO FACTOR_AUTHENTICATION SYSTEM FOR CLOUD_COMPUTING BY ANALYZING SYSTEM_LOGS.pdf started
# Parsing file: RECOMMENDATION USING CONTENT_BASED IMAGE RETRIEVAL.pdf completed
# Parsing file: ETHEREUM BASED BLOCKCHAIN_IMPLEMENTATION OF PEER REVIEW_SYSTEM.pdf started
# Parsing file: Porting Zephyr OS.pdf completed
# Parsing file: Re-Sequencing of Associated News Articles in a Feed Using_Sentiment Analysis_28.pdf started
# Parsing file: INSIDER THREAT DETECTION AND_ADAPTIVE TWO FACTOR_AUTHENTICATION SYSTEM FOR CLOUD_COMPUTING BY ANALYZING SYSTEM_LOGS.pdf completed
# Parsing file: Interactive User Behaviour Analysis and_Recommendation System Using Web Log_Mining_15.pdf started
# Parsing file: HIRING DECISION SUPPORT SYSTEM_13.pdf completed
# Parsing file: Music Discovery Using Content Based Paradigms.pdf started
# Parsing file: ETHEREUM BASED BLOCKCHAIN_IMPLEMENTATION OF PEER REVIEW_SYSTEM.pdf completed
# Parsing file: CLASSIFYING USERS AND IDENTIFYING_USER INTERESTS BASED ON SEMANTIC AND_CONTEXTUAL ANALYSIS.pdf started
# Parsing file: Interactive User Behaviour Analysis and_Recommendation System Using Web Log_Mining_15.pdf completed
# Parsing file: QA GENERATION APPLICATION USING NLP.pdf started
# Parsing file: Music Discovery Using Content Based Paradigms.pdf completed
# Parsing file: RE-ADMISSION RISK PREDICTION FOR_HEART ATTACK.pdf started
# Parsing file: CLASSIFYING USERS AND IDENTIFYING_USER INTERESTS BASED ON SEMANTIC AND_CONTEXTUAL ANALYSIS.pdf completed
# Parsing file: DEEP LEARNING IN MEDICAL IMAGE_ANALYSIS.pdf started
# Parsing file: Re-Sequencing of Associated News Articles in a Feed Using_Sentiment Analysis_28.pdf completed
# Parsing file: Live process migration in mobil e env_63.pdf started
# Parsing file: QA GENERATION APPLICATION USING NLP.pdf completed
# Parsing file: PIXTALK_ PICTURE EXCHANGE COMMUNICATION_FOR AUTISM SPECTRUM DISORDER IN CHILDREN_USING MACHINE LEARNING.pdf started
# Parsing file: RE-ADMISSION RISK PREDICTION FOR_HEART ATTACK.pdf completed
# Parsing file: Integration of DeepLearning4j with Apache Apex framework_60.pdf started
# Parsing file: PIXTALK_ PICTURE EXCHANGE COMMUNICATION_FOR AUTISM SPECTRUM DISORDER IN CHILDREN_USING MACHINE LEARNING.pdf completed
# Parsing file: Improving performance of Virtual Machines by Virtio Bridge Bypass for PCI devices_69.pdf started
# Parsing file: Live process migration in mobil e env_63.pdf completed
# Parsing file: Volunteer Automation For NGO_79.pdf started
# Parsing file: DEEP LEARNING IN MEDICAL IMAGE_ANALYSIS.pdf completed
# Parsing file: An IoT GATEWAY FOR INTERFACING BLE PERIPHERALS TO CLOUD.pdf started
# Parsing file: Integration of DeepLearning4j with Apache Apex framework_60.pdf completed
# Parsing file: IntelligentAssistant.pdf started
# Parsing file: Volunteer Automation For NGO_79.pdf completed
# Parsing file: SIGN LANGUAGE RECOGNITION.pdf started
# Parsing file: An IoT GATEWAY FOR INTERFACING BLE PERIPHERALS TO CLOUD.pdf completed
# Parsing file: Price Elasticity and Optimization_6.pdf started
# Parsing file: Improving performance of Virtual Machines by Virtio Bridge Bypass for PCI devices_69.pdf completed
# Parsing file: Analyzing Product Image-Metadata Based On Click Through Rate For Advertisement Logistics_61.pdf started
# Parsing file: SIGN LANGUAGE RECOGNITION.pdf completed
# Parsing file: Image Generation in the Style of Artists Using Deep Learning_65.pdf started
# Parsing file: IntelligentAssistant.pdf completed
# Parsing file: SMART BUSINESS CONTINUITY APPLICATION.pdf started
# Parsing file: Price Elasticity and Optimization_6.pdf completed
# Parsing file: VIRTUAL MACHINE COMMUNICATION_ANALYSIS.pdf started
# Parsing file: Analyzing Product Image-Metadata Based On Click Through Rate For Advertisement Logistics_61.pdf completed
# Parsing file: NextGen_Router_17.pdf started
# Parsing file: SMART BUSINESS CONTINUITY APPLICATION.pdf completed
# Parsing file: DIMENSION EXTRACTION OF AN OBJECT_USING MACHINE VISION.pdf started
# Parsing file: VIRTUAL MACHINE COMMUNICATION_ANALYSIS.pdf completed
# Parsing file: COGNITIVE INTELLIGENCE AND_KNOWLEDGE BASED CLASSIFICATION_AND REASONING.pdf started
# Parsing file: Image Generation in the Style of Artists Using Deep Learning_65.pdf completed
# Parsing file: Text summarization of any doc using lsa.pdf started
# Parsing file: DIMENSION EXTRACTION OF AN OBJECT_USING MACHINE VISION.pdf completed
# Parsing file: BEAM-DIGITIZING_CONTENT_IN_ADVERTISING.pdf started
# Parsing file: NextGen_Router_17.pdf completed
# Parsing file: TEXT TO IMAGE SYNTHESIS IN FASHION.pdf started
# Parsing file: COGNITIVE INTELLIGENCE AND_KNOWLEDGE BASED CLASSIFICATION_AND REASONING.pdf completed
# Parsing file: Visual Question Answering Using Deep_Learning_30.pdf started
# Parsing file: Text summarization of any doc using lsa.pdf completed
# Parsing file: Project Mycroft AI.pdf started
# Parsing file: TEXT TO IMAGE SYNTHESIS IN FASHION.pdf completed
# Parsing file: Analysis of Indian Stock Market Analysts.pdf started
# Parsing file: BEAM-DIGITIZING_CONTENT_IN_ADVERTISING.pdf completed
# Parsing file: CREDIT CARD FRAUD DETECTION_SYSTEM.pdf started
# Parsing file: Visual Question Answering Using Deep_Learning_30.pdf completed
# Parsing file: CustomerDecisionSupportSystem_39.pdf started
# Parsing file: CREDIT CARD FRAUD DETECTION_SYSTEM.pdf completed
# Parsing file: INTELLIGENT CYBER SECURITY SYSTEM.pdf started
# Parsing file: Project Mycroft AI.pdf completed
# Parsing file: Generic_Traffic_Shaper_19.pdf started
# Parsing file: Analysis of Indian Stock Market Analysts.pdf completed
# Parsing file: PERSONALITY PREDICTION SYSTEM_USING TWITTER DATA.pdf started
# Parsing file: CustomerDecisionSupportSystem_39.pdf completed
# Parsing file: Crop_disease_detection.pdf started
# Parsing file: INTELLIGENT CYBER SECURITY SYSTEM.pdf completed
# Parsing file: DIRECT TRANSFER FROM DATA DEVICES_56.pdf started
# Parsing file: PERSONALITY PREDICTION SYSTEM_USING TWITTER DATA.pdf completed
# Parsing file: NOBODY PARKS HERE.pdf started
# Parsing file: Generic_Traffic_Shaper_19.pdf completed
# Parsing file: Accelerating Foreign Language Learning_62.pdf started
# Parsing file: NOBODY PARKS HERE.pdf completed
# Parsing file: DETECTING CERVICAL ABNORMALITIES_USING MACHINE LEARNING.pdf started
# Parsing file: DIRECT TRANSFER FROM DATA DEVICES_56.pdf completed
# Parsing file: ANALYSIS OF WORKLOAD AND ITS_CHARACHTERISITICS PROVIDED BY THE_HYPERVISOR AND RECOMMEND_OPTIMAL FIT IN CLOUD.pdf started
# Parsing file: Accelerating Foreign Language Learning_62.pdf completed
# Parsing file: SENTIMENT ANALYSIS ON TWITTER JDATA_74.pdf started
# Parsing file: Crop_disease_detection.pdf completed
# Parsing file: Ocr Pre-Processing.pdf started
# Parsing file: ANALYSIS OF WORKLOAD AND ITS_CHARACHTERISITICS PROVIDED BY THE_HYPERVISOR AND RECOMMEND_OPTIMAL FIT IN CLOUD.pdf completed
# Parsing file: AI BUDDY.pdf started
# Parsing file: DETECTING CERVICAL ABNORMALITIES_USING MACHINE LEARNING.pdf completed
# Parsing file: Implementation of QoE-QoS in SDN_52.pdf started
# Parsing file: Ocr Pre-Processing.pdf completed
# Parsing file: Quick Learning Tool.pdf started
# Parsing file: Implementation of QoE-QoS in SDN_52.pdf completed
# Parsing file: EMPREAL_SOFTWARE_FOR_SOLAR_POWERED_ROOFS.pdf started
# Parsing file: SENTIMENT ANALYSIS ON TWITTER JDATA_74.pdf completed
# Parsing file: Multikeyword ranked search over encrypted data.pdf started
# Parsing file: AI BUDDY.pdf completed
# Parsing file: 3D-image terrain classification using machine learning_46.pdf started
# Parsing file: Multikeyword ranked search over encrypted data.pdf completed
# Parsing file: TRANSACTION MONITORING IN PUBLIC_WELFARE PROJECTS USING SMART_CONTRACTS.pdf started
# Parsing file: 3D-image terrain classification using machine learning_46.pdf completed
# Parsing file: Indoor Positioning system with BLE beacons using voronoi mapping.pdf started
# Parsing file: Quick Learning Tool.pdf completed
# Parsing file: A NALYSIS OF G ENE R EGULATION USING_D EEP L EARNING.pdf started
# Parsing file: EMPREAL_SOFTWARE_FOR_SOLAR_POWERED_ROOFS.pdf completed
# Parsing file: Cloud Switch with Cmpatible Library for IoT Devices.pdf started
# Parsing file: TRANSACTION MONITORING IN PUBLIC_WELFARE PROJECTS USING SMART_CONTRACTS.pdf completed
# Parsing file: DEMAND FORECASTING FOR INVENTORY_OPTIMIZATION.pdf started
# Parsing file: DEMAND FORECASTING FOR INVENTORY_OPTIMIZATION.pdf completed
# Parsing file: Adaptive Traffic Congestion Control.pdf started
# Parsing file: Cloud Switch with Cmpatible Library for IoT Devices.pdf completed
# Parsing file: MICRO VIDEO RECOMMENDATION_SYSTEM FOR CONTENT WRITER.pdf started
# Parsing file: MICRO VIDEO RECOMMENDATION_SYSTEM FOR CONTENT WRITER.pdf completed
# Parsing file: DynamicFoodPricing.pdf started
# Parsing file: Adaptive Traffic Congestion Control.pdf completed
# Parsing file: DETECTING STUDENT___S ENGAGEMENT IN_LECTURE USING DEEP LEARNING.pdf started
# Parsing file: A NALYSIS OF G ENE R EGULATION USING_D EEP L EARNING.pdf completed
# Parsing file: AUDIT AND COMPLIANCE IN SERVICE_MANAGEMENT USING BLOCKCHAIN.pdf started
# Parsing file: AUDIT AND COMPLIANCE IN SERVICE_MANAGEMENT USING BLOCKCHAIN.pdf completed
# Parsing file: IT SKILLS TRACKING AND EMPLOYEE ASSESSMEN_2.pdf started
# Parsing file: DETECTING STUDENT___S ENGAGEMENT IN_LECTURE USING DEEP LEARNING.pdf completed
# Parsing file: CONTEXTUAL ANALYSIS BASED ON_SUMMARIZED TEXT OF CONVERSATION.pdf started
# Parsing file: DynamicFoodPricing.pdf completed
# Parsing file: N-SCALAR.pdf started
# Parsing file: CONTEXTUAL ANALYSIS BASED ON_SUMMARIZED TEXT OF CONVERSATION.pdf completed
# Parsing file: Biomedical Tumor Segmentation.pdf started
# Parsing file: N-SCALAR.pdf completed
# Parsing file: GPS SUPPORTED CITY BUS TRACKING AND TRIP PLANNER_53.pdf started
# Parsing file: GPS SUPPORTED CITY BUS TRACKING AND TRIP PLANNER_53.pdf completed
# Parsing file: GESTURE AWARE INTERACTIVE_PRESENTATION SYSTEM.pdf started
# Parsing file: Biomedical Tumor Segmentation.pdf completed
# Parsing file: Smart_Surveillance System_49.pdf started
# Parsing file: GESTURE AWARE INTERACTIVE_PRESENTATION SYSTEM.pdf completed
# Parsing file: SMART CITY GARBAGE CAN_16.pdf started
# Parsing file: SMART CITY GARBAGE CAN_16.pdf completed
# Parsing file: OBSTACLE AVOIDANCE USING_REINFORCEMENT LEARNING.pdf started
# Parsing file: Smart_Surveillance System_49.pdf completed
# Parsing file: ANSWERING OPEN ENDED QUESTIONS_BASED ON IMAGES USING DEEP_LEARNING APPROACH.pdf started
# Parsing file: IT SKILLS TRACKING AND EMPLOYEE ASSESSMEN_2.pdf completed
# Parsing file: AUTOMATIC INFORMATION EXTRACTION_FROM TEXT DOCUMENTS.pdf started
# Parsing file: OBSTACLE AVOIDANCE USING_REINFORCEMENT LEARNING.pdf completed
# Parsing file: UCAN-Unified Communication for Assisting Novice.pdf started
# Parsing file: UCAN-Unified Communication for Assisting Novice.pdf completed
# Parsing file: ANSWERING OPEN ENDED QUESTIONS_BASED ON IMAGES USING DEEP_LEARNING APPROACH.pdf completed
# Parsing file: Dynamic load balancing of web servers.pdf started
# Parsing file: AUTOMATIC INFORMATION EXTRACTION_FROM TEXT DOCUMENTS.pdf completed
# Parsing file: HATE SPEECH DETECTION ON TWITTER_USING SENTIMENT ANALYSIS.pdf started
# Parsing file: HATE SPEECH DETECTION ON TWITTER_USING SENTIMENT ANALYSIS.pdf completed
# Parsing file: Banking_Recommendation_system.pdf started
# Parsing file: Banking_Recommendation_system.pdf completed
# Parsing file: Dynamic load balancing of web servers.pdf completed
# Parsing file: Analysis of Videos using Deep Learning and High Performance_Computing.pdf started
# Parsing file: Analysis of Videos using Deep Learning and High Performance_Computing.pdf completed
# Parsing file: Personality Prediction System.pdf started
# Parsing file: Personality Prediction System.pdf completed
# Parsing file: Transparent Distributed Computing for CUDA_24.pdf started
# Parsing file: Transparent Distributed Computing for CUDA_24.pdf completed
# Parsing file: Indoor Positioning system with BLE beacons using voronoi mapping.pdf completed
# Parsing file: SOFTWARE GPU UTILITIES_32.pdf started
# Parsing file: SOFTWARE GPU UTILITIES_32.pdf completed
# Parsing file: Crop Production Estimation.pdf started
# Parsing file: Crop Production Estimation.pdf completed
# Parsing file: OPTICAL COHERENCE_TOMOGRAPHY(OCT) REPORT_GENERATOR.pdf started
# Parsing file: OPTICAL COHERENCE_TOMOGRAPHY(OCT) REPORT_GENERATOR.pdf completed
# Parsing file: CODE IMPACT ANALYZER.pdf started
# Parsing file: CODE IMPACT ANALYZER.pdf completed
# Parsing file: Developing Cross Platform App For Farmers For Suggesting Agricultural Products.pdf started
# Parsing file: Developing Cross Platform App For Farmers For Suggesting Agricultural Products.pdf completed
# Parsing file: RMI_Based_Custom_Adapter_8.pdf started
# Parsing file: RMI_Based_Custom_Adapter_8.pdf completed
# Parsing file: Video Summarization_31.pdf started
# Parsing file: Video Summarization_31.pdf completed
# Parsing file: Digital_College.pdf started
# Parsing file: Digital_College.pdf completed
#
# ===========Phase 1 ended==========

# %% [markdown]
# # End of phase 1
